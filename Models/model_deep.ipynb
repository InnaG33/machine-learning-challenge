# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in /Applications/anaconda3/lib/python3.7/site-packages (0.0)
# ...

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
len(df)
# Out:
# 6991

# %%
df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
columns = df.keys()
columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# # Select your features (columns)

# %%
list_features = columns[1:]
list_features
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#        'koi_period', 'koi_period_err1', 'koi_period_err2', 'koi_time0bk',
#        'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact', 'koi_impact_err1',
#        'koi_impact_err2', 'koi_duration', 'koi_duration_err1',
#        'koi_duration_err2', 'koi_depth', 'koi_depth_err1', 'koi_depth_err2',
#        'koi_prad', 'koi_prad_err1', 'koi_prad_err2', 'koi_teq', 'koi_insol',
#        'koi_insol_err1', 'koi_insol_err2', 'koi_model_snr', 'koi_tce_plnt_num',
#        'koi_steff', 'koi_steff_err1', 'koi_steff_err2', 'koi_slogg',
#        'koi_slogg_err1', 'koi_slogg_err2', 'koi_srad', 'koi_srad_err1',
#        'koi_srad_err2', 'ra', 'dec', 'koi_kepmag'],
#       dtype='object')

# %%
selected_features = df[list_features]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = selected_features
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4002              0              0              1              0   99.673478
# 4246              0              1              0              0    0.592244
# 548               0              1              1              0    9.991625
# 3953              0              1              0              0  178.412990
# 2362              0              0              0              0   45.294223
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4002     3.463000e-04    -3.463000e-04   219.334830          0.002300
# 4246     9.000000e-08    -9.000000e-08   131.654831          0.000124
# 548      5.360000e-06    -5.360000e-06   137.447816          0.000445
# 3953     3.100000e-05    -3.100000e-05   218.225235          0.000127
# 2362     5.600000e-05    -5.600000e-05   138.678725          0.000987
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %%
len(X_train)
# Out:
# 5243

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_scaler = MinMaxScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=10, activation='relu', input_dim=40))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 0s - loss: 0.2724 - acc: 0.8825
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.2747 - acc: 0.8795
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.2717 - acc: 0.8844
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.2721 - acc: 0.8817
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.2758 - acc: 0.8760
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.2726 - acc: 0.8793
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.2697 - acc: 0.8814
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.2695 - acc: 0.8823
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.2700 - acc: 0.8806
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.2717 - acc: 0.8814
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.2710 - acc: 0.8796
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.2707 - acc: 0.8806
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.2708 - acc: 0.8825
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.2687 - acc: 0.8816
# Epoch 15/100
# 5243/5243 - 0s - loss: 0.2682 - acc: 0.8835
# Epoch 16/100
# 5243/5243 - 0s - loss: 0.2668 - acc: 0.8859
# ...

# %% [markdown]
# # Evaluate and Predict

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1748 - 0s - loss: 0.2895 - acc: 0.8833
# Normal Neural Network - Loss: 0.2895240332223731, Accuracy: 0.8832951784133911

# %%
predictions = model.predict_classes(X_test_scaled)

# %%
encoded_results = label_encoder.inverse_transform(predictions)

# %%
deepmodel_df = pd.DataFrame({"Prediction": encoded_results, "Actual": y_test})
deepmodel_df.reset_index(inplace=True, drop=True)
deepmodel_df
# Out:
#           Prediction          Actual
# 0          CANDIDATE       CANDIDATE
# 1     FALSE POSITIVE  FALSE POSITIVE
# 2     FALSE POSITIVE  FALSE POSITIVE
# 3          CANDIDATE       CANDIDATE
# 4     FALSE POSITIVE  FALSE POSITIVE
# ...              ...             ...
# 1743       CONFIRMED       CONFIRMED
# 1744  FALSE POSITIVE  FALSE POSITIVE
# 1745       CANDIDATE       CONFIRMED
# 1746       CONFIRMED       CONFIRMED
# 1747  FALSE POSITIVE  FALSE POSITIVE
#
# [1748 rows x 2 columns]

# %% [markdown]
# # Save the Model

# %%
# dm_train_score=model.score(X_train_scaled, y_train_categorical)
# dm_test_score=model.score(X_test_scaled, y_test_categorical)
deepmodel_acc = pd.DataFrame({"model_loss": [model_loss], "model_accuracy": [model_accuracy]})
deepmodel_acc
# Out:
#    model_loss  model_accuracy
# 0    0.289524        0.883295

# %%
deepmodel_acc.to_csv("output/deepmodel_acc.csv")

# %%
model.save("DeepModel.h5")
